# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('ur5e_ppo_logs/sb3_ur5e_seed_0.csv.monitor.csv', header=1)
df
# Out:
#               r      l           t
# 0  -8834.670672    653    0.862000
# 1   4706.810942  10000   10.627488
# 2    463.336935  10000   18.192147
# 3   4939.501926  10000   25.212426
# 4  -8546.904276    586   26.051179
# 5   3268.434258  10000   33.760109
# 6  -8474.438791    762   34.134082
# 7  -8580.154973    813   34.516578
# 8  -8106.331971    785   35.505796
# 9  -9178.185739    260   35.626329
# 10 -8180.108537    968   36.092213
# 11 -7435.091108   1010   37.125261
# 12 -8582.319309   1078   37.629829
# 13 -8888.507186    423   38.433211
# 14 -7879.650322   1148   38.977216
# 15 -8690.294410    588   39.257915
# 16 -8242.782571    757   40.171622
# 17 -8830.154917    531   40.418994
# 18  -802.075648  10000   47.997262
# 19  3042.036956  10000   55.522290
# 20 -8380.071997    590   55.789622
# 21 -8189.064063    893   56.762719
# 22 -8867.017344    417   56.960779
# 23  2363.528527  10000   64.521298
# 24 -8539.657216    976   64.999135
# 25 -8544.791583    602   65.279630
# ...

# %%
fig = plt.figure(figsize=(10, 5))
plt.plot(df['t'], df['r'])
plt.xlabel('Timesteps')
plt.ylabel('Mean Reward')
plt.title('PPO2 Training')
plt.show()
